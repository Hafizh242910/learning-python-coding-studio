# %%
# Sequential => terurut
angka = 10

hasil = angka * 20

print(hasil)
# Out:
# 200

# %%
# Selection => Pemilihan
angka = 20

cek_angka = angka % 2

if cek_angka ==0:
    print("Genap")
else:
    print("Ganjil")
# Out:
# Genap

# %%
# iteration
for i in range(10) :
    print("Hello Teman-Teman")
# Out:
# Hello Teman-Teman
# Hello Teman-Teman
# Hello Teman-Teman
# Hello Teman-Teman
# Hello Teman-Teman
# Hello Teman-Teman
# Hello Teman-Teman
# Hello Teman-Teman
# Hello Teman-Teman
# Hello Teman-Teman

# %%
print("Hello World")
# Out:
# Hello World
