# %%
# Latihan Variabel

nama_siswa = "Hafizh"
umur_siswa = "23"
tinggi_siswa = "165.5"

print("Nama:", nama_siswa)
print("Umur:", umur_siswa)
print("Tinggi:", tinggi_siswa)
# Out:
# Nama: Hafizh
# Umur: 23
# Tinggi: 165.5

# %%
# Latihan Tipe Data

teks = "python"
angka_bulat = 50
angka_desimal = 3.15
is_active = True 

print(type(teks))
print(type(angka_bulat))
print(type(angka_desimal))
print(type(is_active))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# Latihan String dan String Format

nama_depan = "Hafizh"
nama_belakang = "Fadhlurrahman"
nama_lengkap = f"{nama_depan} {nama_belakang}"

print(nama_lengkap)
# Out:
# Hafizh Fadhlurrahman
